# %% [markdown]
# # Subset barcode runs
# This Python Jupyter notebook is creates a copy of the barcode runs file that contains just specific samples.
#
# First, import Python modules:

# %%
import os

import pandas as pd

import yaml

# %% [markdown]
# Read in the "master" barcode runs CSV file and the runs used to compute the escape scores for each sample:

# %%
with open('../config.yaml') as f:
    config = yaml.safe_load(f)

barcode_runs_file = os.path.join('../', config['barcode_runs'])
print(f"Reading barcode runs from {barcode_runs_file}")
barcode_runs = pd.read_csv(barcode_runs_file)

escape_score_samples_file = os.path.join('../', config['escape_score_samples'])
print(f"Reading escape score samples from {escape_score_samples_file}")
escape_score_samples = pd.read_csv(escape_score_samples_file)
# Out:
# Reading barcode runs from ../data/barcode_runs.csv
# Reading escape score samples from ../results/escape_scores/samples.csv

# %% [markdown]
# Now read in the samples to subset:

# %%
samples_to_subset_df = pd.read_csv('samples_to_subset.csv')
print('Here are the samples we will subset to:')
display(samples_to_subset_df)

samples_to_subset = samples_to_subset_df['sample'].tolist()
assert len(samples_to_subset) == len(set(samples_to_subset)), 'duplicate samples to subset'
# Out:
# Here are the samples we will subset to:
#         sample
# 0  CAB-A17_139
# 1  CAB-A49_222
# 2  CAB-C19_184

# %% [markdown]
# Now get all the escape-score samples of interest:

# %%
if not set(samples_to_subset).issubset(escape_score_samples['name']):
    raise ValueError(f"Not all samples to subset are in the escape score samples.")
    
samples_subset = (
    escape_score_samples
    .query('name in @samples_to_subset')
    .reset_index(drop=True)
    )

print(f"Here are the samples for which we are subsetting barcode runs:")
display(samples_subset)
# Out:
# Here are the samples for which we are subsetting barcode runs:
#           name library antibody concentration concentration_units    date  \
# 0  CAB-A17_139    lib1  CAB-A17           139           ng_per_mL  220128
# 1  CAB-A17_139    lib2  CAB-A17           139           ng_per_mL  220128
# 2  CAB-A49_222    lib1  CAB-A49           222           ng_per_mL  220128
# 3  CAB-A49_222    lib2  CAB-A49           222           ng_per_mL  220128
# 4  CAB-C19_184    lib1  CAB-C19           184           ng_per_mL  220128
# 5  CAB-C19_184    lib2  CAB-C19           184           ng_per_mL  220128
#
#                       pre_sample                  post_sample  frac_escape  \
# 0  expt_149-151-none-0-reference  expt_149-CAB-A17-139-escape        0.119
# 1  expt_149-151-none-0-reference  expt_149-CAB-A17-139-escape        0.116
# 2  expt_149-151-none-0-reference  expt_150-CAB-A49-222-escape        0.136
# 3  expt_149-151-none-0-reference  expt_150-CAB-A49-222-escape        0.140
# 4  expt_149-151-none-0-reference  expt_151-CAB-C19-184-escape        0.138
# 5  expt_149-151-none-0-reference  expt_151-CAB-C19-184-escape        0.131
#
#    pre_cells_sorted  post_cells_sorted
# 0         1113047.0                NaN
# 1         1119273.0                NaN
# 2         1415076.0                NaN
# 3         1403814.0                NaN
# 4         1400000.0                NaN
# 5         1318247.0                NaN

# %% [markdown]
# Now unfold the samples of interest into the actual relevant barcode runs (this requires getting both the pre- and post-selection run for each sample):

# %%
barcode_runs_subset = (
    samples_subset
    .melt(id_vars=['name', 'library'],
          value_vars=['pre_sample', 'post_sample'],
          value_name='sample',
          var_name='sample_type')
    [['library', 'sample']]
    .drop_duplicates()
    .reset_index(drop=True)
    .merge(barcode_runs,
           how='left',
           on=['library', 'sample'],
           validate='one_to_one',
           )
    )

assert barcode_runs_subset['R1'].notnull().all(), 'some barcode runs missing R1'

barcode_runs_subset_file = 'barcode_runs_subset.csv'
print(f"Here are the subsetted barcode runs. Writing to {barcode_runs_subset_file}")
barcode_runs_subset.to_csv(barcode_runs_subset_file, index=False)
display(barcode_runs_subset)
# Out:
# Here are the subsetted barcode runs. Writing to barcode_runs_subset.csv
#   library                         sample    date    experiment antibody  \
# 0    lib1  expt_149-151-none-0-reference  220128  expt_149-151     none
# 1    lib2  expt_149-151-none-0-reference  220128  expt_149-151     none
# 2    lib1    expt_149-CAB-A17-139-escape  220128      expt_149  CAB-A17
# 3    lib2    expt_149-CAB-A17-139-escape  220128      expt_149  CAB-A17
# 4    lib1    expt_150-CAB-A49-222-escape  220128      expt_150  CAB-A49
# 5    lib2    expt_150-CAB-A49-222-escape  220128      expt_150  CAB-A49
# 6    lib1    expt_151-CAB-C19-184-escape  220128      expt_151  CAB-C19
# 7    lib2    expt_151-CAB-C19-184-escape  220128      expt_151  CAB-C19
#
#   concentration concentration_units       group  selection  frac_escape  \
# 0             0           ng_per_mL  Karolinska  reference          NaN
# 1             0           ng_per_mL  Karolinska  reference          NaN
# 2           139           ng_per_mL  Karolinska     escape        0.119
# 3           139           ng_per_mL  Karolinska     escape        0.116
# 4           222           ng_per_mL  Karolinska     escape        0.136
# 5           222           ng_per_mL  Karolinska     escape        0.140
# 6           184           ng_per_mL  Karolinska     escape        0.138
# 7           184           ng_per_mL  Karolinska     escape        0.131
#
#    cells_sorted                                                 R1
# 0           NaN  /shared/ngs/illumina/agreaney/220203_VH00319_1...
# 1           NaN  /shared/ngs/illumina/agreaney/220203_VH00319_1...
# 2     1113047.0  /shared/ngs/illumina/agreaney/220218_VH00699_6...
# 3     1119273.0  /shared/ngs/illumina/agreaney/220218_VH00699_6...
# 4     1415076.0  /shared/ngs/illumina/agreaney/220218_VH00699_6...
# 5     1403814.0  /shared/ngs/illumina/agreaney/220218_VH00699_6...
# 6     1400000.0  /shared/ngs/illumina/agreaney/220218_VH00699_6...
# 7     1318247.0  /shared/ngs/illumina/agreaney/220218_VH00699_6...
