# %% [markdown]
# # Create SRA submission sheet
# This Python Jupyter notebook creates a BioSample submission sheet for the Sequence Read Archive:
#
# First, import Python modules:

# %%
import datetime
import glob
import itertools
import os

import natsort

import pandas as pd

import yaml

# %% [markdown]
# Display full columns of data frames:

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Read the configuration for the uploads:

# %%
with open('upload_config.yaml') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# Read the Illumina runs to submit:

# %%
print(f"Reading Illumina runs from {config['barcode_runs']}")

illumina_runs = pd.read_csv(config['barcode_runs'])

print('Here are the first few entries in the Illumina runs:')
illumina_runs.head()
# Out:
# Reading Illumina runs from ../data/barcode_runs.csv
# Here are the first few entries in the Illumina runs:
#   library                         sample    date    experiment antibody  \
# 0    lib1  expt_149-151-none-0-reference  220128  expt_149-151     none
# 1    lib2  expt_149-151-none-0-reference  220128  expt_149-151     none
# 2    lib1    expt_149-CAB-A17-139-escape  220128      expt_149  CAB-A17
# 3    lib2    expt_149-CAB-A17-139-escape  220128      expt_149  CAB-A17
# 4    lib1    expt_150-CAB-A49-222-escape  220128      expt_150  CAB-A49
#
#    concentration concentration_units       group  selection  frac_escape  \
# 0              0           ng_per_mL  Karolinska  reference          NaN
# 1              0           ng_per_mL  Karolinska  reference          NaN
# 2            139           ng_per_mL  Karolinska     escape        0.119
# 3            139           ng_per_mL  Karolinska     escape        0.116
# 4            222           ng_per_mL  Karolinska     escape        0.136
#
#    cells_sorted  \
# 0           NaN
# 1           NaN
# 2     1113047.0
# 3     1119273.0
# 4     1415076.0
#
#                                                                                                                       R1
# 0  /shared/ngs/illumina/agreaney/220203_VH00319_144_AAATNGMM5/Unaligned/Project_agreaney/expt_149-151_lib1_ref*.fastq.gz
# 1  /shared/ngs/illumina/agreaney/220203_VH00319_144_AAATNGMM5/Unaligned/Project_agreaney/expt_149-151_lib2_ref*.fastq.gz
# 2     /shared/ngs/illumina/agreaney/220218_VH00699_65_AAAW23WM5/Unaligned/Project_agreaney/expt_149_lib1_abneg*.fastq.gz
# 3     /shared/ngs/illumina/agreaney/220218_VH00699_65_AAAW23WM5/Unaligned/Project_agreaney/expt_149_lib2_abneg*.fastq.gz
# 4     /shared/ngs/illumina/agreaney/220218_VH00699_65_AAAW23WM5/Unaligned/Project_agreaney/expt_150_lib1_abneg*.fastq.gz

# %% [markdown]
# Next make submission entries for the barcode runs, initially in "tidy" format with one FASTQ file per row:

# %%
submissions_tidy = (
    illumina_runs
    .assign(
        biosample_accession=lambda x: config['biosample_accession'],
        library_ID=lambda x: x['library'] + '_' + x['sample'],
        title=lambda x: 'SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for ' + x['sample'],
        library_strategy='AMPLICON',
        library_source='SYNTHETIC',
        library_selection='PCR',
        library_layout='single',
        platform='ILLUMINA',
        instrument_model='Illumina HiSeq 2500',
        design_description='PCR of barcodes from RBD variants',
        filetype='fastq',
        filename_fullpath=lambda x: x['R1'].str.split(';')
                                    .map(lambda flist: list(itertools.chain.from_iterable(glob.glob(f) for f in flist))),       
        )
    .explode('filename_fullpath')
    .assign(filename_fullpath=lambda x: x['filename_fullpath'].str.strip(),
            filename=lambda x: x['filename_fullpath'].map(os.path.basename))
    .drop(columns=illumina_runs.columns)
    .reset_index(drop=True)
    )

assert submissions_tidy['filename_fullpath'].map(os.path.isfile).all()

print('Here are the first few submission entries in tidy format:')
submissions_tidy.head()
# Out:
# Here are the first few submission entries in tidy format:
#   biosample_accession                          library_ID  \
# 0        SAMN26873633  lib1_expt_149-151-none-0-reference
# 1        SAMN26873633  lib1_expt_149-151-none-0-reference
# 2        SAMN26873633  lib1_expt_149-151-none-0-reference
# 3        SAMN26873633  lib1_expt_149-151-none-0-reference
# 4        SAMN26873633  lib2_expt_149-151-none-0-reference
#
#                                                                                            title  \
# 0  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_149-151-none-0-reference
# 1  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_149-151-none-0-reference
# 2  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_149-151-none-0-reference
# 3  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_149-151-none-0-reference
# 4  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_149-151-none-0-reference
#
#   library_strategy library_source library_selection library_layout  platform  \
# 0         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 1         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 2         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 3         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 4         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
#
#       instrument_model                 design_description filetype  \
# 0  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 1  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 2  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 3  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 4  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
#
#                                                                                                                   filename_fullpath  \
# 0  /shared/ngs/illumina/agreaney/220203_VH00319_144_AAATNGMM5/Unaligned/Project_agreaney/expt_149-151_lib1_ref-3_S3_R1_001.fastq.gz
# 1  /shared/ngs/illumina/agreaney/220203_VH00319_144_AAATNGMM5/Unaligned/Project_agreaney/expt_149-151_lib1_ref-1_S1_R1_001.fastq.gz
# 2  /shared/ngs/illumina/agreaney/220203_VH00319_144_AAATNGMM5/Unaligned/Project_agreaney/expt_149-151_lib1_ref-2_S2_R1_001.fastq.gz
# 3  /shared/ngs/illumina/agreaney/220203_VH00319_144_AAATNGMM5/Unaligned/Project_agreaney/expt_149-151_lib1_ref-4_S4_R1_001.fastq.gz
# 4  /shared/ngs/illumina/agreaney/220203_VH00319_144_AAATNGMM5/Unaligned/Project_agreaney/expt_149-151_lib2_ref-4_S8_R1_001.fastq.gz
#
#                                      filename
# 0  expt_149-151_lib1_ref-3_S3_R1_001.fastq.gz
# 1  expt_149-151_lib1_ref-1_S1_R1_001.fastq.gz
# 2  expt_149-151_lib1_ref-2_S2_R1_001.fastq.gz
# 3  expt_149-151_lib1_ref-4_S4_R1_001.fastq.gz
# 4  expt_149-151_lib2_ref-4_S8_R1_001.fastq.gz

# %% [markdown]
# For the actual submission, we need a "wide" data frame that for each unique `sample_name` / `library_ID` gives all of the files each in different columns.
# These should be files without the full path.
#
# First, look at how many files there are for each sample / library:

# %%
(submissions_tidy
 .groupby(['biosample_accession', 'library_ID'])
 .aggregate(n_files=pd.NamedAgg('filename_fullpath', 'count'))
 .sort_values('n_files', ascending=False)
 .reset_index()
 )
# Out:
#   biosample_accession                          library_ID  n_files
# 0        SAMN26873633  lib1_expt_149-151-none-0-reference        4
# 1        SAMN26873633  lib2_expt_149-151-none-0-reference        4
# 2        SAMN26873633    lib1_expt_149-CAB-A17-139-escape        1
# 3        SAMN26873633    lib1_expt_150-CAB-A49-222-escape        1
# 4        SAMN26873633    lib1_expt_151-CAB-C19-184-escape        1
# 5        SAMN26873633    lib2_expt_149-CAB-A17-139-escape        1
# 6        SAMN26873633    lib2_expt_150-CAB-A49-222-escape        1
# 7        SAMN26873633    lib2_expt_151-CAB-C19-184-escape        1

# %% [markdown]
# Now make the wide submission data frame.
# Note we keep only the filename column with the path lacking the full directory information:

# %%
submissions_wide = (
    submissions_tidy
    .assign(
        filename_count=lambda x: x.groupby(['biosample_accession', 'library_ID'])['filename'].cumcount() + 1,
        filename_col=lambda x: 'filename' + x['filename_count'].map(lambda c: str(c) if c > 1 else '')
        )
    .pivot(
        index='library_ID',
        columns='filename_col',
        values='filename',
        )
    )

submissions_wide = (
    submissions_tidy
    .drop(columns=['filename_fullpath', 'filename'])
    .drop_duplicates()
    .merge(submissions_wide[natsort.natsorted(submissions_wide.columns)],
           on='library_ID',
           validate='one_to_one',
           )
    )

print('Here are the first few submission entries in wide format:')
submissions_wide.head()
# Out:
# Here are the first few submission entries in wide format:
#   biosample_accession                          library_ID  \
# 0        SAMN26873633  lib1_expt_149-151-none-0-reference
# 1        SAMN26873633  lib2_expt_149-151-none-0-reference
# 2        SAMN26873633    lib1_expt_149-CAB-A17-139-escape
# 3        SAMN26873633    lib2_expt_149-CAB-A17-139-escape
# 4        SAMN26873633    lib1_expt_150-CAB-A49-222-escape
#
#                                                                                            title  \
# 0  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_149-151-none-0-reference
# 1  SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_149-151-none-0-reference
# 2    SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_149-CAB-A17-139-escape
# 3    SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_149-CAB-A17-139-escape
# 4    SARS-CoV-2 RBD mutational antig Illumina barcode sequencing for expt_150-CAB-A49-222-escape
#
#   library_strategy library_source library_selection library_layout  platform  \
# 0         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 1         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 2         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 3         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
# 4         AMPLICON      SYNTHETIC               PCR         single  ILLUMINA
#
#       instrument_model                 design_description filetype  \
# 0  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 1  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 2  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 3  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
# 4  Illumina HiSeq 2500  PCR of barcodes from RBD variants    fastq
#
#                                      filename  \
# 0  expt_149-151_lib1_ref-3_S3_R1_001.fastq.gz
# 1  expt_149-151_lib2_ref-4_S8_R1_001.fastq.gz
# 2     expt_149_lib1_abneg_S25_R1_001.fastq.gz
# 3     expt_149_lib2_abneg_S26_R1_001.fastq.gz
# 4     expt_150_lib1_abneg_S27_R1_001.fastq.gz
#
#                                     filename2  \
# 0  expt_149-151_lib1_ref-1_S1_R1_001.fastq.gz
# 1  expt_149-151_lib2_ref-3_S7_R1_001.fastq.gz
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                     filename3  \
# 0  expt_149-151_lib1_ref-2_S2_R1_001.fastq.gz
# 1  expt_149-151_lib2_ref-2_S6_R1_001.fastq.gz
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                     filename4
# 0  expt_149-151_lib1_ref-4_S4_R1_001.fastq.gz
# 1  expt_149-151_lib2_ref-1_S5_R1_001.fastq.gz
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN

# %% [markdown]
# Now write the wide submissions data frame to a `*.tsv` file that can be used for uploading the SRA submission website:

# %%
submissions_spreadsheet = 'SRA_submission_spreadsheet.tsv'

submissions_wide.to_csv(submissions_spreadsheet, sep='\t', index=False)

# %% [markdown]
# We also want to write a file with all of the FASTQ files that are in the submission spreadsheet:

# %%
fastq_file_list = 'FASTQs_to_upload.csv'

print(f"Writing list of all the FASTQ files to upload to {fastq_file_list}")

(submissions_tidy
 [['filename_fullpath', 'filename']]
 .to_csv(fastq_file_list, index=False)
 )
# Out:
# Writing list of all the FASTQ files to upload to FASTQs_to_upload.csv
