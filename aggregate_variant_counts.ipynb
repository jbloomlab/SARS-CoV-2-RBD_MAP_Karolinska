# %% [markdown]
# # Aggregate variant counts for all samples
# Separate `Snakemake` rules count the observations of each variant in each sample from the Illumina barcode sequencing.
# This Python Jupyter notebook aggregates all of this counts, and then adds them to a codon variant table.

# %% [markdown]
# ## Set up analysis
# ### Import Python modules.
# Use [plotnine](https://plotnine.readthedocs.io/en/stable/) for ggplot2-like plotting.
#
# The analysis relies heavily on the Bloom lab's [dms_variants](https://jbloomlab.github.io/dms_variants) package:

# %%
import glob
import itertools
import math
import os
import warnings

import Bio.SeqIO

import dms_variants.codonvarianttable
from dms_variants.constants import CBPALETTE
import dms_variants.utils
import dms_variants.plotnine_themes

from IPython.display import display, HTML

import pandas as pd

from plotnine import *

import yaml

# %% [markdown]
# Set [plotnine](https://plotnine.readthedocs.io/en/stable/) theme to the gray-grid one defined in `dms_variants`:

# %%
theme_set(dms_variants.plotnine_themes.theme_graygrid())

# %% [markdown]
# Versions of key software:

# %%
print(f"Using dms_variants version {dms_variants.__version__}")
# Out:
# Using dms_variants version 0.8.5

# %% [markdown]
# Ignore warnings that clutter output:

# %%
warnings.simplefilter('ignore')

# %% [markdown]
# Read the configuration file:

# %%
with open('config.yaml') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# Make output directory if needed:

# %%
os.makedirs(config['counts_dir'], exist_ok=True)

# %% [markdown]
# ## Initialize codon variant table
# Initialize the [CodonVariantTable](https://jbloomlab.github.io/dms_variants/dms_variants.codonvarianttable.html#dms_variants.codonvarianttable.CodonVariantTable) using the wildtype gene sequence and the CSV file with the table of variants:

# %%
wt_seqrecord = Bio.SeqIO.read(config['wildtype_sequence'], 'fasta')
geneseq = str(wt_seqrecord.seq)
primary_target = wt_seqrecord.name
print(f"Read sequence of {len(geneseq)} nt for {primary_target} from {config['wildtype_sequence']}")
      
print(f"Initializing CodonVariantTable from gene sequence and {config['codon_variant_table']}")
      
variants = dms_variants.codonvarianttable.CodonVariantTable(
                geneseq=geneseq,
                barcode_variant_file=config['codon_variant_table'],
                substitutions_are_codon=True,
                substitutions_col='codon_substitutions',
                primary_target=primary_target)
# Out:
# Read sequence of 603 nt for SARS-CoV-2 from data/wildtype_sequence.fasta
# Initializing CodonVariantTable from gene sequence and results/prior_DMS_data/codon_variant_table.csv

# %% [markdown]
# ## Read barcode counts / fates
# Read data frame with list of all samples (barcode runs):

# %%
print(f"Reading list of barcode runs from {config['barcode_runs']}")

barcode_runs = (pd.read_csv(config['barcode_runs'])
                .assign(sample_lib=lambda x: x['sample'] + '_' + x['library'],
                        counts_file=lambda x: config['counts_dir'] + '/' + x['sample_lib'] + '_counts.csv',
                        fates_file=lambda x: config['counts_dir'] + '/' + x['sample_lib'] + '_fates.csv',
                        )
                .drop(columns='R1')  # don't need this column, and very large
                )

assert all(map(os.path.isfile, barcode_runs['counts_file'])), 'missing some counts files'
assert all(map(os.path.isfile, barcode_runs['fates_file'])), 'missing some fates files'

display(HTML(barcode_runs.to_html(index=False)))
# Out:
# Reading list of barcode runs from data/barcode_runs.csv
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>date</th>
#       <th>experiment</th>
#       <th>library</th>
#       <th>antibody</th>
#       <th>concentration</th>
#       <th>concentration_units</th>
#       <th>group</th>
#       <th>selection</th>
#       <th>sample</th>
#       <th>frac_escape</th>
#       <th>cells_sorted</th>
#       <th>sample_lib</th>
#       <th>counts_file</th>
#       <th>fates_file</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>200612</td>
#       <td>expt_2</td>
#       <td>lib1</td>
#       <td>ACE2-CR3022</td>
#       <td>150</td>
#       <td>ng_per_mL</td>
#       <td>CR3022</td>
#       <td>reference</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#       <td>NaN</td>
#       <td>5116406.0</td>
#       <td>expt_2-ACE2-CR3022-150-reference_lib1</td>
#       <td>results/counts/expt_2-ACE2-CR3022-150-reference_lib1_counts.csv</td>
#       <td>results/counts/expt_2-ACE2-CR3022-150-reference_lib1_fates.csv</td>
#     </tr>
#     <tr>
#       <td>200612</td>
#       <td>expt_2</td>
#       <td>lib2</td>
#       <td>ACE2-CR3022</td>
#       <td>150</td>
#       <td>ng_per_mL</td>
#       <td>CR3022</td>
#       <td>reference</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#       <td>NaN</td>
#       <td>5023644.0</td>
#       <td>expt_2-ACE2-CR3022-150-reference_lib2</td>
#       <td>results/counts/expt_2-ACE2-CR3022-150-reference_lib2_counts.csv</td>
#       <td>results/counts/expt_2-ACE2-CR3022-150-reference_lib2_fates.csv</td>
#     </tr>
#     <tr>
#       <td>200612</td>
#       <td>expt_2</td>
#       <td>lib1</td>
#       <td>ACE2-CR3022</td>
#       <td>750</td>
#       <td>ng_per_mL</td>
#       <td>CR3022</td>
#       <td>escape</td>
#       <td>expt_2-ACE2-CR3022-750-escape</td>
#       <td>0.101</td>
#       <td>334507.0</td>
#       <td>expt_2-ACE2-CR3022-750-escape_lib1</td>
#       <td>results/counts/expt_2-ACE2-CR3022-750-escape_lib1_counts.csv</td>
#       <td>results/counts/expt_2-ACE2-CR3022-750-escape_lib1_fates.csv</td>
#     </tr>
#     <tr>
#       <td>200612</td>
#       <td>expt_2</td>
#       <td>lib2</td>
#       <td>ACE2-CR3022</td>
#       <td>750</td>
#       <td>ng_per_mL</td>
#       <td>CR3022</td>
#       <td>escape</td>
#       <td>expt_2-ACE2-CR3022-750-escape</td>
#       <td>0.084</td>
#       <td>312614.0</td>
#       <td>expt_2-ACE2-CR3022-750-escape_lib2</td>
#       <td>results/counts/expt_2-ACE2-CR3022-750-escape_lib2_counts.csv</td>
#       <td>results/counts/expt_2-ACE2-CR3022-750-escape_lib2_fates.csv</td>
#     </tr>
#     <tr>
#       <td>200612</td>
#       <td>expt_2</td>
#       <td>lib1</td>
#       <td>ACE2-CR3022</td>
#       <td>150</td>
#       <td>ng_per_mL</td>
#       <td>CR3022</td>
#       <td>escape</td>
#       <td>expt_2-ACE2-CR3022-150-escape</td>
#       <td>0.066</td>
#       <td>246724.0</td>
#       <td>expt_2-ACE2-CR3022-150-escape_lib1</td>
#       <td>results/counts/expt_2-ACE2-CR3022-150-escape_lib1_counts.csv</td>
#       <td>results/counts/expt_2-ACE2-CR3022-150-escape_lib1_fates.csv</td>
#     </tr>
#     <tr>
#       <td>
fates.csv</td>
#     </tr>
#     <tr>
#       <td>200615</td>
#       <td>expt_5</td>
#       <td>lib2</td>
#       <td>COV2-2479</td>
#       <td>400</td>
#       <td>ng_per_mL</td>
#       <td>Crowe</td>
#       <td>escape</td>
#       <td>expt_5-COV2-2479-400-escape</td>
#       <td>0.044</td>
#       <td>582089.0</td>
#       <td>expt_5-COV2-2479-400-escape_lib2</td>
#       <td>results/counts/expt_5-COV2-2479-400-escape_lib2_counts.csv</td>
#       <td>results/counts/expt_5-COV2-2479-400-escape_lib2_fates.csv</td>
#     </tr>
#     <tr>
#       <td>200615</td>
#       <td>expt_5</td>
#       <td>lib1</td>
#       <td>COV2-2479</td>
#       <td>400</td>
#       <td>ng_per_mL</td>
#       <td>Crowe</td>
#       <td>escape</td>
#       <td>expt_5-COV2-2479-400-escape</td>
#       <td>0.050</td>
#       <td>684856.0</td>
#       <td>expt_5-COV2-2479-400-escape_lib1</td>
#       <td>results/counts/expt_5-COV2-2479-400-escape_lib1_counts.csv</td>
#       <td>results/counts/expt_5-COV2-2479-400-escape_lib1_fates.csv</td>
#     </tr>
#     <tr>
#       <td>200615</td>
#       <td>expt_6</td>
#       <td>lib1</td>
#       <td>2C02</td>
#       <td>400</td>
#       <td>ng_per_mL</td>
#       <td>Ellebedy</td>
#       <td>escape</td>
#       <td>expt_6-2C02-400-escape</td>
#       <td>0.157</td>
#       <td>1771544.0</td>
#       <td>expt_6-2C02-400-escape_lib1</td>
#       <td>results/counts/expt_6-2C02-400-escape_lib1_counts.csv</td>
#       <td>results/counts/expt_6-2C02-400-escape_lib1_fates.csv</td>
#     </tr>
#     <tr>
#       <td>200615</td>
#       <td>expt_6</td>
#       <td>lib2</td>
#       <td>2C02</td>
#       <td>400</td>
#       <td>ng_per_mL</td>
#       <td>Ellebedy</td>
#       <td>escape</td>
#       <td>expt_6-2C02-400-escape</td>
#       <td>0.178</td>
#       <td>2163094.0</td>
#       <td>expt_6-2C02-400-escape_lib2</td>
#       <td>results/counts/expt_6-2C02-400-escape_lib2_counts.csv</td>
#       <td>results/counts/expt_6-2C02-400-escape_lib2_fates.csv</td>
#     </tr>
#     <tr>
#       <td>200616</td>
#       <td>expt_7-11</td>
#       <td>lib1</td>
#       <td>none</td>
#       <td>0</td>
#       <td>ng_per_mL</td>
#       <td>none</td>
#       <td>reference</td>
#       <td>expt_7-11-none-0-reference</td>
#       <td>NaN</td>
#       <td>160000000.0</td>
#       <td>expt_7-11-none-0-reference_lib1</td>
#       <td>results/counts/expt_7-1

# %% [markdown]
# Confirm sample / library combinations unique:

# %%
assert len(barcode_runs) == len(barcode_runs.groupby(['sample', 'library']))

# %% [markdown]
# Make sure the the libraries for which we have barcode runs are all in our variant table:

# %%
unknown_libs = set(barcode_runs['library']) - set(variants.libraries)
if unknown_libs:
    raise ValueError(f"Libraries with barcode runs not in variant table: {unknown_libs}")

# %% [markdown]
# Now concatenate the barcode counts and fates for each sample:

# %%
counts = pd.concat([pd.read_csv(f) for f in barcode_runs['counts_file']],
                   sort=False,
                   ignore_index=True)

print('First few lines of counts data frame:')
display(HTML(counts.head().to_html(index=False)))

fates = pd.concat([pd.read_csv(f) for f in barcode_runs['fates_file']],
                  sort=False,
                  ignore_index=True)

print('First few lines of fates data frame:')
display(HTML(fates.head().to_html(index=False)))
# Out:
# First few lines of counts data frame:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>barcode</th>
#       <th>count</th>
#       <th>library</th>
#       <th>sample</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>TTCCAAAATATTGTCA</td>
#       <td>194290</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#     </tr>
#     <tr>
#       <td>TAGTAACAATGCGGTA</td>
#       <td>94565</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#     </tr>
#     <tr>
#       <td>TTAATTAGTATCAGGT</td>
#       <td>55277</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#     </tr>
#     <tr>
#       <td>CCGGACACATAGCTTA</td>
#       <td>32741</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#     </tr>
#     <tr>
#       <td>GTAAGAAGCTTACCAG</td>
#       <td>30550</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#     </tr>
#   </tbody>
# </table>
# First few lines of fates data frame:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>fate</th>
#       <th>count</th>
#       <th>library</th>
#       <th>sample</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>valid barcode</td>
#       <td>17555016</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#     </tr>
#     <tr>
#       <td>failed chastity filter</td>
#       <td>6735444</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#     </tr>
#     <tr>
#       <td>low quality barcode</td>
#       <td>3522488</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#     </tr>
#     <tr>
#       <td>invalid barcode</td>
#       <td>2103266</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#     </tr>
#     <tr>
#       <td>unparseable barcode</td>
#       <td>1003679</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Examine fates of parsed barcodes
# First, we'll analyze the "fates" of the parsed barcodes.
# These fates represent what happened to each Illumina read we parsed:
#  - Did the barcode read fail the Illumina chastity filter?
#  - Was the barcode *unparseable* (i.e., the read didn't appear to be a valid barcode based on flanking regions)?
#  - Was the barcode sequence too *low quality* based on the Illumina quality scores?
#  - Was the barcode parseable but *invalid* (i.e., not in our list of variant-associated barcodes in the codon variant table)?
#  - Was the barcode *valid*, and so will be added to variant counts.
#
# First, we just write a CSV file with all the barcode fates:

# %%
fatesfile = os.path.join(config['counts_dir'], 'barcode_fates.csv')
print(f"Writing barcode fates to {fatesfile}")
fates.to_csv(fatesfile, index=False)
# Out:
# Writing barcode fates to results/counts/barcode_fates.csv

# %% [markdown]
# Next, we tabulate the barcode fates in wide format:

# %%
display(HTML(fates
             .pivot_table(columns='fate',
                          values='count',
                          index=['sample', 'library'])
             .applymap('{:.1e}'.format)  # scientific notation
             .to_html()
             ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>fate</th>
#       <th>failed chastity filter</th>
#       <th>invalid barcode</th>
#       <th>low quality barcode</th>
#       <th>unparseable barcode</th>
#       <th>valid barcode</th>
#     </tr>
#     <tr>
#       <th>sample</th>
#       <th>library</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="2" valign="top">expt_10-COV2-2832-400-escape</th>
#       <th>lib1</th>
#       <td>1.2e+06</td>
#       <td>6.4e+05</td>
#       <td>1.8e+06</td>
#       <td>2.5e+05</td>
#       <td>1.5e+07</td>
#     </tr>
#     <tr>
#       <th>lib2</th>
#       <td>1.3e+06</td>
#       <td>1.4e+06</td>
#       <td>1.3e+06</td>
#       <td>5.5e+05</td>
#       <td>8.8e+06</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">expt_100-M19-day-119-200-escape</th>
#       <th>lib1</th>
#       <td>5.3e+04</td>
#       <td>2.8e+05</td>
#       <td>1.2e+05</td>
#       <td>4.1e+04</td>
#       <td>1.9e+06</td>
#     </tr>
#     <tr>
#       <th>lib2</th>
#       <td>6.4e+04</td>
#       <td>2.8e+05</td>
#       <td>1.4e+05</td>
#       <td>5.0e+04</td>
#       <td>2.4e+06</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">expt_101-M01-day-119-80-escape</th>
#       <th>lib1</th>
#       <td>7.0e+04</td>
#       <td>3.6e+05</td>
#       <td>1.6e+05</td>
#       <td>5.5e+04</td>
#       <td>2.7e+06</td>
#     </tr>
#     <tr>
#       <th>lib2</th>
#       <td>6.2e+04</td>
#       <td>2.6e+05</td>
#       <td>1.3e+05</td>
#       <td>4.9e+04</td>
#       <td>2.1e+06</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">expt_102-M03-day-119-200-escape</th>
#       <th>lib1</th>
#       <td
+06</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">expt_110-M15-day-119-200-escape</th>
#       <th>lib1</th>
#       <td>1.1e+05</td>
#       <td>4.7e+05</td>
#       <td>2.4e+05</td>
#       <td>9.5e+04</td>
#       <td>3.8e+06</td>
#     </tr>
#     <tr>
#       <th>lib2</th>
#       <td>1.2e+05</td>
#       <td>4.2e+05</td>
#       <td>2.5e+05</td>
#       <td>1.1e+05</td>
#       <td>4.0e+06</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">expt_111-M20-day-119-200-escape</th>
#       <th>lib1</th>
#       <td>1.3e+05</td>
#       <td>5.0e+05</td>
#       <td>2.6e+05</td>
#       <td>8.6e+04</td>
#       <td>4.2e+06</td>
#     </tr>
#     <tr>
#       <th>lib2</th>
#       <td>9.0e+04</td>
#       <td>3.2e+05</td>
#       <td>1.9e+05</td>
#       <td>6.1e+04</td>
#       <td>3.1e+06</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">expt_112-M21-day-119-200-escape</th>
#       <th>lib1</th>
#       <td>8.6e+04</td>
#       <td>4.0e+05</td>
#       <td>1.8e+05</td>
#       <td>6.0e+04</td>
#       <td>3.0e+06</td>
#     </tr>
#     <tr>
#       <th>lib2</th>
#       <td>9.9e+04</td>
#       <td>3.9e+05</td>
#       <td>2.1e+05</td>
#       <td>7.5e+04</td>
#       <td>3.5e+06</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">expt_113-M22-day-119-200-escape</th>
#       <th>lib1</th>
#       <td>1.1e+05</td>
#       <td>4.9e+05</td>
#       <td>2.2e+05</td>
#       <td>7.7e+04</td>
#       <td>3.6e+06</td>
#     </tr>
#     <tr>
#       <th>lib2</th>
#       <td>9.7e+04</td>
#       <td>3.7e+05</td>
#       <td>2.1e+05</td>
#       <td>7.3e+04</td>
#       <td>3.4e+06</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">expt_114-M23-day-119-200-escape</th>
#       <th>lib1</th>
#       <td>1.0e+05</td>
#       <td>4.6e+05</td>
#       <td>2.2e+05</td>
#       <td>7.1e+04</td>
#       <td>3.5e+06</td>
#     </tr>
#     <tr>
#       <th>lib2</th>
#       <td>1.1e+05</td>
#       <td>4.1e+05</td>
#       <td>2.3e+05</td>
#       <td>8.6e+04</td>
#       <td>3.7e+06</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">expt_115-NHP-serum-1000-escape</th>
#       <th>lib1</th>
#       <td>1.1e+05</td>
#       <td>4.5e+05</td>
#       <td>2.2e+05</td>
#       <td>9.8e+04</td>
#       <td>3.6e+06</td>
#     </tr>
#     <tr>
#       <th>lib2</th>
#       <td>1.1e+05</td>
#       <td>4.0e+05</td>
#       <td>2.3e+05</td>
#       <td>7.9e+04</td>
#       <td>3.7e+06</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">expt_116-COV2-2381-400-escape</th>
#       <th>lib1</th>
#       <td>3.6e+05</td>
#       <td>1.3e+06</td>
#       <td>7.6e+05</td>
#       <td>2.1e+05</td>
#       <td>1.2e+07</td>
#     </tr>
#     <tr>
#       <th>lib2</th>
#       <td>3.7e+05</td>
#       <td>1.2e+06</td>
#       <td>7.4e+05</td>
#       <

# %% [markdown]
# Now we plot the barcode-read fates for each library / sample, showing the bars for valid barcodes in orange and the others in gray.
# We see that the largest fraction of barcode reads correspond to valid barcodes, and most of the others are invalid barcodes (probably because the map to variants that aren't present in our variant table since we didn't associate all variants with barcodes). The exception to this is lib2 Titeseq_03_bin3; the PCR for this sample in the original sequencing run failed, so we followed it up with a single MiSeq lane. We did not filter out the PhiX reads from this data before parsing, so these PhiX reads will deflate the fraction of valid barcode reads as expected, but does not indicate any problems.

# %%
ncol = 4
nfacets = len(fates.groupby(['sample', 'library']))

barcode_fate_plot = (
    ggplot(
        fates
        .assign(sample=lambda x: pd.Categorical(x['sample'],
                                                x['sample'].unique(),
                                                ordered=True),
                fate=lambda x: pd.Categorical(x['fate'],
                                              x['fate'].unique(),
                                              ordered=True),
                is_valid=lambda x: x['fate'] == 'valid barcode'
                ), 
        aes('fate', 'count', fill='is_valid')) +
    geom_bar(stat='identity') +
    facet_wrap('~ sample + library', ncol=ncol) +
    scale_fill_manual(CBPALETTE, guide=False) +
    theme(figure_size=(3.25 * ncol, 2 * math.ceil(nfacets / ncol)),
          axis_text_x=element_text(angle=90),
          panel_grid_major_x=element_blank()
          ) +
    scale_y_continuous(labels=dms_variants.utils.latex_sci_not,
                       name='number of reads')
    )

_ = barcode_fate_plot.draw()

# %% [markdown]
# ## Add barcode counts to variant table
# Now we use the [CodonVariantTable.add_sample_counts_df](https://jbloomlab.github.io/dms_variants/dms_variants.codonvarianttable.html#dms_variants.codonvarianttable.CodonVariantTable.add_sample_counts_df) method to add the barcode counts to the variant table:

# %%
variants.add_sample_counts_df(counts)

# %% [markdown]
# The variant table now has a `variant_count_df` attribute that gives a data frame of all the variant counts.
# Here are the first few lines:

# %%
display(HTML(variants.variant_count_df.head().to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>target</th>
#       <th>library</th>
#       <th>sample</th>
#       <th>barcode</th>
#       <th>count</th>
#       <th>variant_call_support</th>
#       <th>codon_substitutions</th>
#       <th>aa_substitutions</th>
#       <th>n_codon_substitutions</th>
#       <th>n_aa_substitutions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>BM48-31</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#       <td>CGGTTACCAACCTGGA</td>
#       <td>118</td>
#       <td>3</td>
#       <td>BM48-31</td>
#       <td>BM48-31</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>BM48-31</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#       <td>ACCGCACGCTGATAAT</td>
#       <td>113</td>
#       <td>4</td>
#       <td>BM48-31</td>
#       <td>BM48-31</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>BM48-31</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#       <td>GAAAGGCTGTATCCCA</td>
#       <td>109</td>
#       <td>4</td>
#       <td>BM48-31</td>
#       <td>BM48-31</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>BM48-31</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#       <td>ACCCGAACCAGGTTGC</td>
#       <td>95</td>
#       <td>2</td>
#       <td>BM48-31</td>
#       <td>BM48-31</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>BM48-31</td>
#       <td>lib1</td>
#       <td>expt_2-ACE2-CR3022-150-reference</td>
#       <td>GACAAATGGCAATGCC</td>
#       <td>93</td>
#       <td>1</td>
#       <td>BM48-31</td>
#       <td>BM48-31</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Write the variant counts data frame to a CSV file.
# It can then be used to re-initialize a [CodonVariantTable](https://jbloomlab.github.io/dms_variants/dms_variants.codonvarianttable.html#dms_variants.codonvarianttable.CodonVariantTable) via its [from_variant_count_df](https://jbloomlab.github.io/dms_variants/dms_variants.codonvarianttable.html#dms_variants.codonvarianttable.CodonVariantTable.from_variant_count_df) method:

# %%
print(f"Writing variant counts to {config['variant_counts']}")
variants.variant_count_df.to_csv(config['variant_counts'], index=False, compression='gzip')
# Out:
# Writing variant counts to results/counts/variant_counts.csv.gz

# %% [markdown]
# The [CodonVariantTable](https://jbloomlab.github.io/dms_variants/dms_variants.codonvarianttable.html#dms_variants.codonvarianttable.CodonVariantTable) has lots of nice functions that can be used to analyze the counts it contains.
# However, we do that in the next notebook so we don't have to re-run this entire (rather computationally intensive) notebook every time we want to analyze a new aspect of the counts.
